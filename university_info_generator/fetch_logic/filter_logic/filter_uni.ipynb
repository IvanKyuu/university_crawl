# %%
import pandas as pd

# %%
target_uni_lst = [
"Algoma University",
"University of Toronto",
"Carleton University",
"Dominican University College/Collège Universitaire Dominicain",
"Lakehead University",
"Laurentian University of Sudbury/Université Laurentienne de Sudbury",
"McMaster University",
"Nipissing University",
"University of Ottawa",
"Saint Paul University",
"Queen's University",
"Ryerson University",
"Trent University",
"Western University",
"Wilfrid Laurier University",
"University of Windsor",
"York University",
"Ontario College of Art and Design University",
"University of Ontario Institute of Technology",
"Université de Hearst",
"Huntington University",
"University of British Columbia",
"Simon Fraser University",
"University of Victoria",
"University of Calgary",
"University of Alberta",
"McGill University",
"Université de Montréal",
"Université Laval",
"Université de Sherbrooke",
"Concordia University",
"Dalhousie University",
"Memorial University of Newfoundland",
"University of Manitoba",
"University of Saskatchewan",
"University of Regina",
"University of New Brunswick",
"St. Francis Xavier University",
"Mount Allison University",
"University of Prince Edward Island",
]

# %%
for i in target_uni_lst:
    print(i, sep="\n")
# Out:
# Algoma University
# University of Toronto
# Carleton University
# Dominican University College/Collège Universitaire Dominicain
# Lakehead University
# Laurentian University of Sudbury/Université Laurentienne de Sudbury
# McMaster University
# Nipissing University
# University of Ottawa
# Saint Paul University
# Queen's University
# Ryerson University
# Trent University
# Western University
# Wilfrid Laurier University
# University of Windsor
# York University
# Ontario College of Art and Design University
# University of Ontario Institute of Technology
# Université de Hearst
# Huntington University
# University of British Columbia
# Simon Fraser University
# University of Victoria
# University of Calgary
# University of Alberta
# McGill University
# Université de Montréal
# Université Laval
# Université de Sherbrooke
# Concordia University
# Dalhousie University
# Memorial University of Newfoundland
# University of Manitoba
# University of Saskatchewan
# University of Regina
# ...

# %%
canada_df = pd.read_csv("~/Uforse/university_crawl/university_info_generator/fetch_logic/filter_logic/all_universities_canada_info.csv")

# %%
canada_df.head()
# Out:
#                                  index  id_  \
# 0                    Algoma University   71
# 1                University of Toronto   49
# 2                University of Calgary   92
# 3  Memorial University of Newfoundland    1
# 4   University of Prince Edward Island    2
#
#                        university_name abbreviation                  website  \
# 0                    Algoma University     Algoma U   https://www.algomau.ca
# 1                University of Toronto       U of T  https://www.utoronto.ca
# 2                University of Calgary     UCalgary  https://www.ucalgary.ca
# 3  Memorial University of Newfoundland          MUN       https://www.mun.ca
# 4   University of Prince Edward Island         UPEI      https://www.upei.ca
#
#                                            wikipedia    university_type  \
# 0    https://en.wikipedia.org/wiki/Algoma_University  Public University
# 1  https://en.wikipedia.org/wiki/University_of_To...  Public University
# ...

# %%
filtered_df = canada_df[canada_df['university_name'].isin(target_uni_lst)]

# %%
filtered_df.to_csv("all_universities_canada_info_filtered.csv", index=False)

# %%
filtered_df.head()
# Out:
#                                  index  id_  \
# 0                    Algoma University   71
# 1                University of Toronto   49
# 2                University of Calgary   92
# 3  Memorial University of Newfoundland    1
# 4   University of Prince Edward Island    2
#
#                        university_name abbreviation                  website  \
# 0                    Algoma University     Algoma U   https://www.algomau.ca
# 1                University of Toronto       U of T  https://www.utoronto.ca
# 2                University of Calgary     UCalgary  https://www.ucalgary.ca
# 3  Memorial University of Newfoundland          MUN       https://www.mun.ca
# 4   University of Prince Edward Island         UPEI      https://www.upei.ca
#
#                                            wikipedia    university_type  \
# 0    https://en.wikipedia.org/wiki/Algoma_University  Public University
# 1  https://en.wikipedia.org/wiki/University_of_To...  Public University
# ...

# %%
print(len(filtered_df.index))
# Out:
# 39
