# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('./data.xlsx')

# Display the first few rows of the dataframe
print(df.head())

# Get basic information about the dataframe
print(df.info())
# Out:
#    ID                                                学校名 abbreviation  \
# 0  36                                   Brock University           BU
# 1  38                                Carleton University           CU
# 2  25                               Concordia University           CU
# 3   7                               Dalhousie University          Dal
# 4  39  Dominican University College/Collège Universit...      DUC/CUD
#
#                                 website  \
# 0                    https://brocku.ca
# 1               https://www.carleton.ca
# 2              https://www.concordia.ca
# 3                    https://www.dal.ca
# 4  https://www.collegedominicain.ca/en/
#
#                                            wikipedia               学校类型  \
# 0    https://en.wikipedia.org/wiki/Brock_University   Public University
# 1  https://en.wikipedia.org/wiki/Carleton_University  Public University
# 2  https://en.wikipedia.org/wiki/Concordia_Univer...  Public University
# 3  https://en.wikipedia.org/wiki/Dalhousie_Univer...  Public University
# 4  https://en.wikipedia.org/wiki/Dominican_Univer...     Public College
#
#                   毕业时间                                               地理位置  \
# 0  2024-03-04 00:00:00  St. Catharines, Ontario, Canada\nHamilton, Ont...
# 1                    4                            Ottawa, Ontario, Canada
# 2                    4                           Montreal, Quebec, Canada
# 3                    4  Halifax, Nova Scotia, Canada\n Truro, Nova Sco...
# 4                    4                            Ottawa, Ontario, Canada
#
#     毕业率                本地学生学费  ... 美国新闻2023排名 泰晤士2024排名 软科世界大学2023排名  \
# 0  0.87            CAD $6,476  ...     1394.0       NaN          NaN
# 1  0.89         CAD $6,058.57  ...      526.0       NaN      501-600
# 2  0.89   CAD $2,328 - $7,227  ...      653.0   501–600      501-600
# 3  0.89  CAD $8,000 - $18,000  ...      314.0   301–350      301-400
# 4  0.89            CAD $6,500  ...        NaN       NaN          NaN
#
#                                               学校重要日历  \
# 0                https://brocku.ca/important-dates/
# 1               https://carleton.ca/important-dates/
# 2  https://www.concordia.ca/academics/graduate/ca...
# 3                   https://academiccalendar.dal.ca/
# 4                                                NaN
#
#                                                 统计数据  \
# 0  Undergraduate Programs: 82\nMaster's Programs:...
# 1  Undergraduate Programs: 99\n Master's Programs...
# 2  Undergraduate Programs: 99\n Master's Programs...
# 3  Undergraduate Programs: 147\n Master's Program...
# 4  Undergraduate Programs: 2\n Master's Programs:...
#
#                                                 热门专业  \
# 0  Goodman School of Business\nFaculty of Applied...
# 1  Environmental Engineering Program\n Communicat...
# 2  Mathematics Program\n Education Program\n Busi...
# 3  Education Program\n Sauder Business School\n E...
# 4  Philosophy Program\n Theology Program\n Ethics...
#
#                                                   专业  \
# 0  Sport-related programs\nBusiness and Managemen...
# 1  Bachelor of Health Sciences (BHSc)\n Architect...
# 2  Bachelor of Arts (BA) - Psychology\nBachelor o...
# 3  Accounting\n Architecture\n Arts & Social Scie...
# 4  Bachelor of Theology - B.Th.\n Certificate in ...
#
#                                                   院校  \
# 0  Accounting\nActing\nAdult Education\nApplied L...
# 1         Faculty of Public Affairs\n Faculty of ...
# 2  Arts and Science\n Gina Cody School of Enginee...
# 3  Architecture and Planning, Faculty of\n Arts a...
# 4        Faculty of Philosophy\n Faculty of Theology
#
#                                                 学校特色             其他
# 0  Brock University is one of Canada's top post-s...            NaN
# 1  Carleton University is characterized by a stro...  Wisdom Tettey
# 2  Concordia University is located in the vibrant...            NaN
# 3  Dalhousie University is recognized for its div...            NaN
# 4  Dominican University College (DUC) is characte...            NaN
#
# [5 rows x 23 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            33 non-null     object
#  1   学校名           33 non-null     object
#  2   abbreviation  33 non-null     object
#  3   website       33 non-null     object
#  4   wikipedia     33 non-null     object
#  5   学校类型          33 non-null     object
#  6   毕业时间          33 non-null     object
#  7   地理位置          33 non-null     object
#  8   毕业率           29 non-null     float64
#  9   本地学生学费        33 non-null     object
#  10  国际学生学费        32 non-null     object
#  11  QS2024排名      13 non-null     object
#  12  简介            33 non-null     object
#  13  美国新闻2023排名    14 non-null     float64
#  14  泰晤士2024排名     12 non-null     object
#  15  软科世界大学2023排名  13 non-null     object
#  16  学校重要日历        32 non-null     object
#  17  统计数据          32 non-null     object
#  18  热门专业          32 non-null     object
#  19  专业            33 non-null     object
#  20  院校            33 non-null     object
#  21  学校特色          33 non-null     object
#  22  其他            1 non-null      object
# dtypes: float64(2), object(21)
# memory usage: 6.1+ KB
# None

# %%
import pandas as pd
from googletrans import Translator
import time
import concurrent.futures
import threading

local = threading.local()

# Function to get or create a thread-local translator
def get_translator():
    if not hasattr(local, 'translator'):
        local.translator = Translator()
    return local.translator

# Function to translate text with error handling and rate limiting
def translate_text(text):
    if not isinstance(text, str):
        return text
    try:
        translator = get_translator()
        time.sleep(0.1)  # Reduced sleep time
        return translator.translate(text, src='fr', dest='en').text
    except Exception as e:
        print(f"Translation error: {e}")
        return text

# Function to translate a column
def translate_column(column):
    return df[column].apply(translate_text)

# Get list of columns to translate (only text columns)
columns_to_translate = df.select_dtypes(include=['object']).columns

# Use ThreadPoolExecutor to parallelize translation
with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    # Submit translation tasks for each column
    future_to_column = {executor.submit(translate_column, column): column for column in columns_to_translate}
    
    # Process completed tasks
    for future in concurrent.futures.as_completed(future_to_column):
        column = future_to_column[future]
        try:
            df[column] = future.result()
            print(f"Translated column: {column}")
        except Exception as exc:
            print(f'{column} generated an exception: {exc}')

# Save the translated dataframe to a new Excel file
df.to_excel('./data_translated_threaded.xlsx', index=False)

print("Translation complete. Saved as 'data_translated_threaded.xlsx'")
# Out:
# Translated column: ID
# Translated column: website
# Translated column: abbreviation
# Translated column: wikipedia
# Translated column: 学校名
# Translated column: 学校类型
# Translated column: 毕业时间
# Translated column: QS2024排名
# Translated column: 泰晤士2024排名
# Translated column: 软科世界大学2023排名
# Translated column: 国际学生学费
# Translated column: 本地学生学费
# Translated column: 地理位置
# Translated column: 简介
# Translated column: 学校重要日历
# Translated column: 专业
# Translated column: 其他
# Translated column: 院校
# Translated column: 热门专业
# Translated column: 学校特色
# Translated column: 统计数据
# Translation complete. Saved as 'data_translated_threaded.xlsx'
# /tmp/ipykernel_14388/306724261.py:49: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   df.to_excel('./data_translated_threaded.xlsx', index=False)

# %%
import pandas as pd
from googletrans import Translator
import time
import concurrent.futures
import threading

local = threading.local()

# Function to get or create a thread-local translator
def get_translator():
    if not hasattr(local, 'translator'):
        local.translator = Translator()
    return local.translator

# Function to translate text with error handling and rate limiting
def translate_text(text):
    if not isinstance(text, str):
        return text
    try:
        translator = get_translator()
        time.sleep(0.1)  # Reduced sleep time
        return translator.translate(text, src='en', dest='zh-cn').text
    except Exception as e:
        print(f"Translation error: {e}")
        return text

# Function to translate a column
def translate_column(column):
    return df[column].apply(translate_text)

# Get list of columns to translate (only text columns)
columns_to_translate = df.select_dtypes(include=['object']).columns

# Use ThreadPoolExecutor to parallelize translation
with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    # Submit translation tasks for each column
    future_to_column = {executor.submit(translate_column, column): column for column in columns_to_translate}
    
    # Process completed tasks
    for future in concurrent.futures.as_completed(future_to_column):
        column = future_to_column[future]
        try:
            df[column] = future.result()
            print(f"Translated column: {column}")
        except Exception as exc:
            print(f'{column} generated an exception: {exc}')

# Save the translated dataframe to a new Excel file
df.to_excel('./data_translated_threaded_ch.xlsx', index=False)

print("Translation complete. Saved as 'data_translated_threaded_ch.xlsx'")
# Out:
# Translated column: ID
# Translated column: website
# Translated column: 学校名
# Translated column: 学校类型
# Translated column: wikipedia
# Translated column: 毕业时间
# Translated column: abbreviation
# Translated column: QS2024排名
# Translated column: 泰晤士2024排名
# Translated column: 软科世界大学2023排名
# Translated column: 本地学生学费
# Translated column: 简介
# Translated column: 国际学生学费
# Translated column: 地理位置
# Translated column: 学校重要日历
# Translated column: 统计数据
# Translated column: 其他
# Translated column: 热门专业
# Translated column: 专业
# Translated column: 院校
# Translated column: 学校特色
# Translation complete. Saved as 'data_translated_threaded_ch.xlsx'
# /tmp/ipykernel_14388/2675027757.py:49: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   df.to_excel('./data_translated_threaded_ch.xlsx', index=False)

# %%
import pandas as pd

# Read the two Excel files
df1 = pd.read_excel('data_translated_threaded.xlsx')
df2 = pd.read_excel('data_translated_threaded_ch.xlsx')

# Determine the number of rows to process
max_rows = max(len(df1), len(df2))

# Create a new empty dataframe to store the result
result_df = pd.DataFrame()

# Alternate rows from each dataframe
for i in range(max_rows):
    if i < len(df1):
        result_df = pd.concat([result_df, df1.iloc[[i]]], ignore_index=True)
    if i < len(df2):
        result_df = pd.concat([result_df, df2.iloc[[i]]], ignore_index=True)

# Save the result to a new Excel file
result_df.to_excel('combined_alternating.xlsx', index=False)

print("Combination complete. Saved as 'combined_alternating.xlsx'")
# Out:
# Combination complete. Saved as 'combined_alternating.xlsx'
# /tmp/ipykernel_14388/4234425928.py:21: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   result_df.to_excel('combined_alternating.xlsx', index=False)
